# %%
import enerhabitat as eh
file = "../epw/MEX_MOR_Cuernavaca-Matamoros.Intl.AP.767260_TMYx.2004-2018.epw"

# %%
eh.config.to_dict()
# Out:
# {'La': 2.5,
#  'Nx': 200,
#  'ho': 13,
#  'hi': 8.6,
#  'dt': 600,
#  'AIR_DENSITY': 1.1797660470258469,
#  'AIR_HEAT_CAPACITY': 1005.458757}

# %%
eh.config.Nx = 30
prueba = eh.System(eh.Location(file))
prueba.info()
# Out:
# <class 'enerhabitat.System'>
# Location: Cuernavaca-Matamoros.Intl.AP, MOR
# Tilt: 90°
# Azimuth: 0°
# Absortance: 0.8

# %%
eh.config.version
# Out:
# 1

# %%
eh.config.file
# Out:
# Error: materials.ini not found

# %%
eh.config.file = "../eh_config/materials.ini"

# %%
eh.config.info()
# Out:
#  -- Current Config Parameters --
# Materials file: ../eh_config/materials.ini
# La (Length of dummy frame): 2.5 m
# Nx (Number of discretization elements): 30
# ho (Outdoor convective coefficient): 13 W/m²K
# hi (Indoor convective coefficient): 8.6 W/m²K
# dt (Time step): 600 seconds
#
# AIR_DENSITY: 1.1797660470258469 kg/m³
# AIR_HEAT_CAPACITY: 1005.458757 J/kgK

# %%
eh.config.file
# Out:
# '../eh_config/materials.ini'

# %%
eh.config.materials_dict()
# Out:
# {'Acero': <enerhabitat.config.Config.materials_dict.<locals>.Material at 0x1eecf596da0>,
#  'Adobe': <enerhabitat.config.Config.materials_dict.<locals>.Material at 0x1eee68e8a90>,
#  'Ladrillo': <enerhabitat.config.Config.materials_dict.<locals>.Material at 0x1eee68e8250>,
#  'Concreto estÃ¡ndard': <enerhabitat.config.Config.materials_dict.<locals>.Material at 0x1eee68e81f0>,
#  'Mortero': <enerhabitat.config.Config.materials_dict.<locals>.Material at 0x1eee68e8190>,
#  'Yeso': <enerhabitat.config.Config.materials_dict.<locals>.Material at 0x1eee68e8130>,
#  'Poliestireno alta densidad': <enerhabitat.config.Config.materials_dict.<locals>.Material at 0x1eee68e80d0>,
#  'EPS': <enerhabitat.config.Config.materials_dict.<locals>.Material at 0x1eee68e8070>,
#  'CAD': <enerhabitat.config.Config.materials_dict.<locals>.Material at 0x1eee68b3f10>}

# %%
eh.config.materials_list()
# Out:
# ['Acero',
#  'Adobe',
#  'Ladrillo',
#  'Concreto estÃ¡ndard',
#  'Mortero',
#  'Yeso',
#  'Poliestireno alta densidad',
#  'EPS',
#  'CAD']
